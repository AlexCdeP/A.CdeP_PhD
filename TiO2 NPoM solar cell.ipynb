# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
# %matplotlib inline
import nplab.datafile as df
import scipy.signal as sig
import scipy.constants as const
import peakutils
import numpy as np
import datetime
from peakutils.plot import plot as pplot
from parula import cm_data
from matplotlib.colors import LinearSegmentedColormap 
from matplotlib.collections import LineCollection
import os
import Alexsdatafuncs
import matplotlib.cm as cm
import time
import scipy.integrate as integrate
import scipy.special as special

# %%
data_f_2.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-ad4df90c6838> in <module>()
# ----> 1 data_f_2.close()
#
# NameError: name 'data_f_2' is not defined

# %%
data_f_3.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-706f4316560c> in <module>()
# ----> 1 data_f_3.close()
#
# NameError: name 'data_f_3' is not defined

# %%
data_f = df.open_file(set_current = False)
fname = data_f.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/2018.10.10 - Cantilever contacting on 60nm AuNPs on TiO2 with Alex/2018-10-10.h5

# %%
data_f_2 = df.open_file(set_current = False)
fname_2 = data_f_2.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/2018.10.24 - Cantilever contacting on 60nm AuNPs on TiO2 with Alex/2018-10-24.h5

# %%
data_f_4 = df.open_file(set_current = False)
fname_4 = data_f_4.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/2018.11.22 - Cantilever on TiO2 with Alex/2018-11-22.h5

# %%
data_f_4.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-237658a7ff27> in <module>()
# ----> 1 data_f_4.close()
#
# NameError: name 'data_f_4' is not defined

# %%
ele_meas = data_f['Electronic_contacting_experiment']

# %%
ele_meas_2 = data_f_2['Electronic_contacting_experiment']

# %%
ele_meas_4 = data_f_4['Electronic_contacting_experiment']

# %%
#First set of data
curr_1 = ele_meas.values()[1].values()[0]
time_1 = ele_meas.values()[1].values()[3]
volt_1 = ele_meas.values()[1].values()[4]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_1, curr_1)
ax1[1].set_xlabel('Time (s)')
ax1[1].set_ylabel('Voltage (A)')
ax1[0].set_ylabel('Current(V)')
ax1[1].plot(time_1, volt_1)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
#fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Meas1_none.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e7c1310c4511> in <module>()
#       1 #First set of data
# ----> 2 curr_1 = ele_meas.values()[1].values()[0]
#       3 time_1 = ele_meas.values()[1].values()[3]
#       4 volt_1 = ele_meas.values()[1].values()[4]
#       5
#
# NameError: name 'ele_meas' is not defined

# %%
#First set of data
curr_2 = ele_meas.values()[2].values()[0]
time_2 = ele_meas.values()[2].values()[3]
volt_2 = ele_meas.values()[2].values()[4]

fig2, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_2, curr_2)
ax1[1].set_xlabel('Time (s)')
ax1[1].set_ylabel('Voltage (A)')
ax1[0].set_ylabel('Current(V)')
ax1[1].plot(time_2, volt_2)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig2.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M2_swon.png', bbox_inches='tight')

# %%
#First set of data
curr_3 = ele_meas.values()[13].values()[0]
time_3 = ele_meas.values()[13].values()[3]
volt_3 = ele_meas.values()[13].values()[4]

fig1, ax1 = plt.subplots(2, sharex=True)
ax1[0].plot(time_3, curr_3)
ax1[1].set_xlabel('Time (s)')
ax1[1].set_ylabel('Voltage (V)')
ax1[0].set_ylabel('Current(A)')
ax1[1].plot(time_3, volt_3)

# %%
divI_V
# Out:
# [inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  -inf,
#  inf,
#  -inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  0.0002367392,
#  0.00030808907,
#  0.00034401921,
#  0.00042132911,
#  0.00037708902,
#  0.00040468905,
#  0.00036064934,
#  0.00036730911,
#  0.0002423093,
#  9.7099364e-05,
#  0.00025547933,
#  0.00033154892,
#  0.00022457926,
#  0.00016652905,
#  6.2779007e-05,
#  6.8368994e-05,
#  4.4879016e-05,
#  -2.1630627e-05,
#  3.1539003e-05,
#  3.4079334e-05,
#  4.5919252e-05,
#  -2.9031071e-05,
#  1.542901e-05,
#  6.3998872e-05,
#  1.453941e-05,
#  -6.6609118e-06,
#  6.0468894e-05,
#  7.0058944e-05,
#  -4.45408e-05,
#  1.5188562e-06,
#  8.469101e-06,
#  -4.5620825e-05,
#  -0.00014367061,
#  -0.00011271084,
#  -0.00012310068,
#  -0.00016076058,
#  -0.00012766066,
# ...

# %%
fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[1].plot(time_4[0:2200], volt_4[0:2200])
ax1[0].plot(time_4[0:2200], curr_4[0:2200])
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Meas_2_area2_res_check.png', bbox_inches='tight')

# %%
#First set of data
curr_5 = ele_meas.values()[18].values()[0]
time_5 = ele_meas.values()[18].values()[1]
volt_5 = ele_meas.values()[18].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[1].plot(time_5, volt_5)
ax1[0].plot(time_5, curr_5)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)

#fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Meas_2_area2_none.png', bbox_inches='tight')

# %%
#First set of data
curr_6 = ele_meas.values()[19].values()[0]
time_6 = ele_meas.values()[19].values()[1]
volt_6 = ele_meas.values()[19].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_6, curr_6)
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].set_xlabel('Time(s)')
ax1[1].plot(time_6, volt_6)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M3_a2_swon.png', bbox_inches='tight')

# %%
#First set of data
curr_6 = ele_meas.values()[19].values()[0]
time_6 = ele_meas.values()[19].values()[1]
volt_6 = ele_meas.values()[19].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_6[4500:5500], curr_6[4500:5500])
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].set_xlabel('Time(s)')
ax1[1].plot(time_6[4500:6000], volt_6[4500:6000])

ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)

fig2.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Looking for steps.png', bbox_inches='tight')

# %%
#First set of data
curr_7 = ele_meas.values()[20].values()[0]
time_7 = ele_meas.values()[20].values()[1]
volt_7 = ele_meas.values()[20].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_7, curr_7)
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].set_xlabel('Time(s)')
ax1[1].plot(time_7, volt_7)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M3_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_8 = ele_meas.values()[21].values()[0]
time_8 = ele_meas.values()[21].values()[1]
volt_8 = ele_meas.values()[21].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_8, curr_8)
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].set_xlabel('Time(s)')
ax1[1].plot(time_8, volt_8)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M4_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_9 = ele_meas.values()[22].values()[0]
time_9 = ele_meas.values()[22].values()[1]
volt_9 = ele_meas.values()[22].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_9, curr_9)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_9, volt_9)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M5_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_10 = ele_meas.values()[23].values()[0]
time_10= ele_meas.values()[23].values()[1]
volt_10 = ele_meas.values()[23].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_10, curr_10)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_10, volt_10)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M6_a2_swoff.png', bbox_inches='tight')

# %%
#First set of data
curr_11 = ele_meas.values()[3].values()[0]
time_11= ele_meas.values()[3].values()[1]
volt_11 = ele_meas.values()[3].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_11, curr_11)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_11, volt_11)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M7_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_12 = ele_meas.values()[4].values()[0]
time_12= ele_meas.values()[4].values()[1]
volt_12 = ele_meas.values()[4].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_12, curr_12)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_12, volt_12)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M8_a2_swoff.png', bbox_inches='tight')

# %%
#First set of data
curr_13 = ele_meas.values()[5].values()[0]
time_13= ele_meas.values()[5].values()[1]
volt_13 = ele_meas.values()[5].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_13, curr_13)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_13, volt_13)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M9_a2_swon_off.png', bbox_inches='tight')

# %%
#First set of data
curr_14 = ele_meas.values()[6].values()[0]
time_14= ele_meas.values()[6].values()[1]
volt_14 = ele_meas.values()[6].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_14, curr_14)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_14, volt_14)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M10_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_15 = ele_meas.values()[7].values()[0]
time_15= ele_meas.values()[7].values()[1]
volt_15 = ele_meas.values()[7].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_15, curr_15)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_15, volt_15)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M11_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_16 = ele_meas.values()[8].values()[0]
time_16= ele_meas.values()[8].values()[1]
volt_16 = ele_meas.values()[8].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_16, curr_16)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_16, volt_16)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M12_a2_swoff.png', bbox_inches='tight')

# %%
#First set of data
curr_17 = ele_meas.values()[9].values()[0]
time_17= ele_meas.values()[9].values()[1]
volt_17 = ele_meas.values()[9].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_17, curr_17)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_17, volt_17)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M13_a2_swon.png', bbox_inches='tight')

# %%
#First set of data
curr_18 = ele_meas.values()[10].values()[0]
time_18= ele_meas.values()[10].values()[1]
volt_18 = ele_meas.values()[10].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_18, curr_18)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_18, volt_18)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M14_a2_swoff.png', bbox_inches='tight')

# %%
#First set of data
curr_19 = ele_meas.values()[11].values()[0]
time_19= ele_meas.values()[11].values()[1]
volt_19 = ele_meas.values()[11].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_19, curr_19)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_19, volt_19)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M15_a2_cond.png', bbox_inches='tight')

# %%
#First set of data
curr_20 = ele_meas.values()[12].values()[0]
time_20= ele_meas.values()[12].values()[1]
volt_20 = ele_meas.values()[12].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_20, curr_20)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_20, volt_20)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M16_a2_swon_off.png', bbox_inches='tight')

# %%
#First set of data
curr_21 = ele_meas.values()[14].values()[0]
time_21= ele_meas.values()[14].values()[1]
volt_21 = ele_meas.values()[14].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_21, curr_21)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_21, volt_21)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M17_a2_swoff.png', bbox_inches='tight')

# %%
#First set of data
curr_22 = ele_meas.values()[15].values()[0]
time_22= ele_meas.values()[15].values()[1]
volt_22 = ele_meas.values()[15].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_22, curr_22)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_22, volt_22)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M18_a2_swon_off.png', bbox_inches='tight')

# %%
#First set of data
curr_23 = ele_meas.values()[16].values()[0]
time_23= ele_meas.values()[16].values()[1]
volt_23 = ele_meas.values()[16].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_23, curr_23)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_23, volt_23)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/M19_a3_break.png', bbox_inches='tight')

# %%
print np.shape(time_exp2[...]), np.shape(curr_exp2)
# Out:
# (231L,) (9643,)

# %%
#First set of data
curr_exp2 = ele_meas_2.values()[1].values()[0]
time_exp2= ele_meas_2.values()[1].values()[1]
volt_exp2 = ele_meas_2.values()[1].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2, curr_exp2)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2, volt_exp2)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M1.png', bbox_inches='tight')

# %%
#First set of data
curr_exp2_1 = ele_meas_2.values()[2].values()[0]
time_exp2_1 = ele_meas_2.values()[2].values()[1]
volt_exp2_1 = ele_meas_2.values()[2].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_1, curr_exp2_1)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_1, volt_exp2_1)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M2.png', bbox_inches='tight')

# %%
#First set of data
curr_exp2_2 = ele_meas_2.values()[3].values()[0]
time_exp2_2 = ele_meas_2.values()[3].values()[1]
volt_exp2_2 = ele_meas_2.values()[3].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_2, curr_exp2_2)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_2, volt_exp2_2)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M3.png', bbox_inches='tight')

# %%
#First set of data
curr_exp2_3 = ele_meas_2.values()[4].values()[0]
time_exp2_3= ele_meas_2.values()[4].values()[1]
volt_exp2_3 = ele_meas_2.values()[4].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_3, curr_exp2_3)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_3, volt_exp2_3)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M4.png', bbox_inches='tight')

# %%
#First set of data
curr_exp2_4 = ele_meas_2.values()[5].values()[0]
time_exp2_4= ele_meas_2.values()[5].values()[1]
volt_exp2_4 = ele_meas_2.values()[5].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_4, curr_exp2_4)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_4, volt_exp2_4)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M5.png', bbox_inches='tight')

# %%
#First set of data
curr_exp2_5 = ele_meas_2.values()[6].values()[0]
time_exp2_5= ele_meas_2.values()[6].values()[1]
volt_exp2_5 = ele_meas_2.values()[6].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp2_5, curr_exp2_5, color = 'r')
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_5, volt_exp2_5)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6IVvst_w_shutter.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_5[0:500], curr_exp2_5[0:500])
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_5[0:500], volt_exp2_5[0:500])
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_rescheck.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))
ax1.plot(time_exp2_5[0:500], volt_exp2_5[0:500]/curr_exp2_5[0:500])
ax1.set_ylabel('Resistance', fontsize = 20)
ax1.tick_params(axis='y', labelsize=15)
ax1.set_xlabel("Time (s)", fontsize =20)
ax1.tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_init_R.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))
ax1.plot(time_exp2_5[3:200], volt_exp2_5[3:200]/curr_exp2_5[3:200])
ax1.set_ylabel('Resistance', fontsize = 20)
ax1.tick_params(axis='y', labelsize=15)
ax1.set_xlabel("Time (s)", fontsize =20)
ax1.tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_init_R_steps.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(2, sharex=False, figsize = (8,10))
ax1[0].plot(time_exp2_5[1:202], (curr_exp2_5[1:202]/volt_exp2_5[1:202])/(7.7480917310*10**(-5)))
ax1[1].plot(time_4, divI_V_M2A2)
ax1[0].set_ylabel('Conductance', fontsize = 20)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[0].set_xlabel("Time (s)", fontsize =20)
ax1[0].tick_params(axis='x', labelsize=15)
ax1[1].set_xlim(0,210)
ax1[1].set_ylim(-0.0001, 0.0012)
ax1[0].set_xlim(0,5.2)
ax1[0].set_ylim(-2,9)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_init_G_steps.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))
ax1.plot(time_exp2_5[210:500], volt_exp2_5[210:500]/curr_exp2_5[210:500])
ax1.set_ylabel('Resistance', fontsize = 20)
ax1.tick_params(axis='y', labelsize=15)
ax1.set_xlabel("Time (s)", fontsize =20)
ax1.tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_init_R_steps.png', bbox_inches='tight')

# %%
fig1, ax1 = plt.subplots(2, sharex=True, figsize = (8,10))
ax1[0].plot(time_exp2_5[0:50], curr_exp2_5[0:50])
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_5[0:50], volt_exp2_5[0:50])
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6_smoothsteps.png', bbox_inches='tight')

# %%
dI_dV = []
for i in range(0, len(curr_exp2_5)):
    dI_dV.append(curr_exp2_5[i]/volt_exp2_5[i])

fig1, ax1 = plt.subplots(2, figsize = (8,10))
ax1[0].plot(time_exp2_5[0:202], dI_dV[0:202], color = "r")
ax1[1].plot(time_4, divI_V_M2A2)
ax1[0].set_xlabel('Time(s)')
ax1[0].set_ylabel('dI/dV', fontsize = 20)
ax1[0].set_xlabel('Time(s)', fontsize = 20)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='x', labelsize=15)
ax1[1].set_xlim(0,110)
ax1[1].set_ylim(-0.0001, 0.0012)
ax1[1].tick_params(axis='x', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].set_ylabel('dI/dV', fontsize = 20)
ax1[0].set_xlim(0,2.5)
ax1[0].set_ylim(0.0004, 0.0007)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/dI_dV_Exp2_M6_vs_Exp1_M1.png', bbox_inches='tight')
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in float_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dI_dV = []
for i in range(0, len(curr_exp2_5)):
    dI_dV.append(curr_exp2_5[i]/volt_exp2_5[i])

fig1, ax1 = plt.subplots(1, figsize = (13,8))
ax1.plot(volt_4[0:10000], divI_V_M2A2[0:10000], label = "Exp. 1")
ax1.plot(volt_exp2_5[0:202], dI_dV[0:202], label = "Exp. 2",color="r")
ax1.set_xlabel('Voltage(V)', fontsize = 20)
ax1.set_ylabel('dI/dV', fontsize = 20)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='x', labelsize=15)
ax1.set_ylim(0.0005,0.00105)
ax1.set_xlim(0,0.01)
ax1.legend(fontsize = 20)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/dI_dV_Exp2_M6andExp1_m2_vs_V.png', bbox_inches='tight')
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in float_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp2_5[5500:12000], curr_exp2_5[5500:12000], color = 'r')
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp2_5[5500:12500], volt_exp2_5[5500:12500])
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Hot electron resonator/Exp2M6IVvst_w_shutter_selected.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_1 = ele_meas_4.values()[2].values()[0]
time_exp4_1= ele_meas_4.values()[2].values()[1]
volt_exp4_1 = ele_meas_4.values()[2].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_1, curr_exp4_1, label = "OFF - S1")
ax1[0].plot(time_exp4_2, curr_exp4_2, label = "ON - S2")
ax1[0].plot(time_exp4_3, curr_exp4_3, label = "OFF - S3")
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_2, volt_exp4_2)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
ax1[0].legend(fontsize = 20)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M1_LightOnOFF.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_2 = ele_meas_4.values()[9].values()[0]
time_exp4_2= ele_meas_4.values()[9].values()[1]
volt_exp4_2 = ele_meas_4.values()[9].values()[2]

fig1, ax1 = plt.subplots(2, sharex=False, figsize = (20,10))
ax1[0].plot(time_exp4_2, curr_exp4_2)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_2, volt_exp4_2)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M1_LightOn.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_3 = ele_meas_4.values()[10].values()[0]
time_exp4_3= ele_meas_4.values()[10].values()[1]
volt_exp4_3 = ele_meas_4.values()[10].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_3, curr_exp4_3)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_3, volt_exp4_3)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M1_LightOn.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_4 = ele_meas_4.values()[11].values()[0]
time_exp4_4= ele_meas_4.values()[11].values()[1]
volt_exp4_4 = ele_meas_4.values()[11].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_4, curr_exp4_4, label = "ON - 1")
ax1[0].plot(time_exp4_5, curr_exp4_5, label = "OFF - 2")
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_4, volt_exp4_4)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
ax1[0].legend(fontsize = 20)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M2_LightONOFF.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_5 = ele_meas_4.values()[12].values()[0]
time_exp4_5 = ele_meas_4.values()[12].values()[1]
volt_exp4_5 = ele_meas_4.values()[12].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_5, curr_exp4_5)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_5, volt_exp4_5)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M1_LightOn.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_6 = ele_meas_4.values()[3].values()[0]
time_exp4_6 = ele_meas_4.values()[3].values()[1]
volt_exp4_6 = ele_meas_4.values()[3].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_6, curr_exp4_6)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_6, volt_exp4_6)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
ax1[0].set_xlim(0,11)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M3_LightOnConduct.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_7 = ele_meas_4.values()[7].values()[0]
time_exp4_7 = ele_meas_4.values()[7].values()[1]
volt_exp4_7 = ele_meas_4.values()[7].values()[2]

fig1, ax1 = plt.subplots(2, sharex=True, figsize = (20,10))
ax1[0].plot(time_exp4_7, curr_exp4_7)
ax1[1].set_xlabel('Time(s)')
ax1[1].set_ylabel('Voltage(V)')
ax1[0].set_ylabel('Current (A)')
ax1[1].plot(time_exp4_7, volt_exp4_7)
ax1[1].set_ylabel('Voltage (V)', fontsize = 20)
ax1[0].set_ylabel('Current (A)', fontsize = 20)
ax1[1].set_xlabel('Time(s)', fontsize = 20)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='y', labelsize=15)
ax1[0].tick_params(axis='y', labelsize=15)
ax1[1].tick_params(axis='x', labelsize=15)
fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M4_LightSwitch.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_1 = ele_meas_4.values()[2].values()[0]
time_exp4_1= ele_meas_4.values()[2].values()[1]
volt_exp4_1 = ele_meas_4.values()[2].values()[2]

fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax1.plot(volt_exp4_1[4000:6000], curr_exp4_1[4000:6000], label = "Closed - S1")

#ax1.set_ylabel('Current (A)', fontsize = 15)
ax1.yaxis.set_label_position('right')
#ax1.set_xlabel('Voltage (V)', fontsize = 15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='x', labelsize=15)

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/Exp4M4_LightSwitch.png', bbox_inches='tight')

# %%
#First set of data
curr_exp4_7 = ele_meas_4.values()[7].values()[0]
time_exp4_7 = ele_meas_4.values()[7].values()[1]
volt_exp4_7 = ele_meas_4.values()[7].values()[2]

fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax1.plot(volt_exp4_7[0:16], curr_exp4_7[0:16], label = "Closed - S1")
ax1.plot(volt_exp4_7[16:22], curr_exp4_7[16:22], label = "Closed - S1")
ax1.plot(volt_exp4_7[22:28], curr_exp4_7[22:28], label = "Closed - S1")
#ax1.set_ylabel('Current (A)', fontsize = 15)
ax1.yaxis.set_label_position('right')
#ax1.set_xlabel('Voltage (V)', fontsize = 15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='x', labelsize=15)
ax1.legend(fontsize = 15)

# %%
curr_exp4_6 = ele_meas_4.values()[3].values()[0]
time_exp4_6 = ele_meas_4.values()[3].values()[1]
volt_exp4_6 = ele_meas_4.values()[3].values()[2]

fig1, ax1 = plt.subplots(1, sharex=True, figsize = (7,7))

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax1.plot(volt_exp4_6, curr_exp4_6, label = "Closed - S1")
#ax1.set_ylabel('Current (A)', fontsize = 15)
ax1.yaxis.set_label_position('right')
#ax1.set_xlabel('Voltage (V)', fontsize = 15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.tick_params(axis='x', labelsize=15)
ax1.legend(fontsize = 15)

# %%
#Import dark field data for 60nm NP on Au/TiO2
data_f_5 = df.open_file(set_current = False)
fname_5 = data_f_5.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/2019-01-16_Au_TiO2_60nmAuNP_NaClDep_DF_spectra_150119.h5

# %%
data_f_5.close()

# %%
#Import dark field data for 60nm NP on Au/TiO2
df_meas = data_f_5['OceanOpticsSpectrometer']

# %%
#Put all data into arrays
df_store_1 = []
df_bg_store_1 = []
df_ref_store_1 = []
df_plot = []
wl = df_meas[df_meas.keys()[i]].attrs['wavelengths']

for i in range(0, len(df_meas.values())):
    df_store_1.append(df_meas.values()[i].value)
    df_bg_store_1.append(df_meas[df_meas.keys()[i]].attrs['background'])
    df_ref_store_1.append(df_meas[df_meas.keys()[i]].attrs['reference'])
    df_plot.append((df_store_1[i] - df_bg_store_1[i])/(df_ref_store_1[i] - df_bg_store_1[i]))

# %%
#Caluculate average and standard deviations for this data set
av_df_1 = np.mean(df_plot, axis=0)
stdv_df_1 = np.std(df_plot, axis=0)
stdv_df_n_1 = stdv_df_1/np.sqrt(len(df_plot))
av_df_f_1 = sig.savgol_filter(av_df_1, 23, 4)
stdv_df_n_f_1 = sig.savgol_filter(stdv_df_n_1, 23, 4)

# %%
#Plot the average with corresponding standard deviation for 60nm NP NaCl deposited on TiO2/Au
fig1 = plt.figure(1, [7,7])
ax1 = fig1.add_subplot(111)
ax1.plot(wl, av_df_f_1*100)
ax1.plot(wl, (av_df_f_1 - stdv_df_n_f_1)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_1 + stdv_df_n_f_1)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_1 - stdv_df_n_f_1)*100,
                (av_df_f_1 + stdv_df_n_f_1)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.set_xlim(410, 900)
ax1.set_ylim(0, 0.15)
ax1.set_ylabel("Scattering (%)", fontsize = 25)
ax1.set_xlabel("Wavelength (nm)", fontsize = 25)
ax1.tick_params(axis='x', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.set_title("60nm NPs on TiO$_2$/Au with NaCl", fontsize = 20)


#ax2 = ax1.twiny()
e = 1243.125/wl
#ax2.set_xlim(ax2.get_xlim())

# %%
#Import dark field data for 60nm NP on Au/TiO2
data_f_6 = df.open_file(set_current = False)
fname_6 = data_f_6.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/2019-02-05_60nm_Au_only.h5

# %%
data_f_6.close()

# %%
#Import dark field data for 60nm NP on Au only
df_meas_2 = data_f_6['OceanOpticsSpectrometer']

# %%
#Put all data into arrays
df_store_2 = []
df_bg_store_2 = []
df_ref_store_2 = []
df_plot_2 = []
wl = df_meas_2[df_meas_2.keys()[i]].attrs['wavelengths']

for i in range(0, len(df_meas_2.values())):
    df_store_2.append(df_meas_2.values()[i].value)
    df_bg_store_2.append(df_meas_2[df_meas_2.keys()[i]].attrs['background'])
    df_ref_store_2.append(df_meas_2[df_meas_2.keys()[i]].attrs['reference'])
    df_plot_2.append((df_store_2[i] - df_bg_store_2[i])/(df_ref_store_2[i] - df_bg_store_2[i]))
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in divide
#   if sys.path[0] == '':
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in divide
#   if sys.path[0] == '':

# %%
#Caluculate average and standard deviations for this data set
av_df_2 = np.mean(df_plot_2, axis=0)
stdv_df_2 = np.std(df_plot_2, axis=0)
stdv_df_n_2 = stdv_df_2/np.sqrt(len(df_plot_2))
av_df_f_2 = sig.savgol_filter(av_df_2, 23, 4)
stdv_df_n_f_2 = sig.savgol_filter(stdv_df_n_2, 23, 4)
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\scipy\signal\_savitzky_golay.py:187: RankWarning: Polyfit may be poorly conditioned
#   xx_edge, polyorder)
# C:\Users\alexc\Anaconda2\lib\site-packages\scipy\signal\_savitzky_golay.py:187: RankWarning: Polyfit may be poorly conditioned
#   xx_edge, polyorder)

# %%
len(df_plot_2)
# Out:
# 154

# %%
#Plot the average with corresponding standard deviation for 60nm NP NaCl deposited on TiO2/Au
fig1 = plt.figure(1, [7,7])
ax1 = fig1.add_subplot(111)
ax1.plot(wl, av_df_f_2*100, label = "60nm NPs on Au")
ax1.plot(wl, (av_df_f_2 - stdv_df_n_f_2)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_2 + stdv_df_n_f_2)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_2 - stdv_df_n_f_2)*100,
                (av_df_f_2 + stdv_df_n_f_2)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.plot(wl, av_df_f_1*100, label = "60nm NPs on 3nm TiO$_2$/Au")
ax1.plot(wl, (av_df_f_1 - stdv_df_n_f_1)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_1 + stdv_df_n_f_1)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_1 - stdv_df_n_f_1)*100,
                (av_df_f_1 + stdv_df_n_f_1)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.set_xlim(410, 900)
ax1.set_ylim(0, 0.15)
ax1.set_ylabel("Scattering (%)", fontsize = 25)
ax1.set_xlabel("Wavelength (nm)", fontsize = 25)
ax1.tick_params(axis='x', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.legend(fontsize = 12)


#ax2 = ax1.twiny()
e = 1243.125/wl
#ax2.set_xlim(ax2.get_xlim())

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/60nm NP DF on vs off TiO2.png', bbox_inches='tight')

# %%
#Import dark field data for 60nm NP on Au following O2 plasma etch
data_f_7 = df.open_file(set_current = False)
fname_7 = data_f_7.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/2019-02-06_O2_plasmaetch_Au.h5

# %%
data_f_7.close()

# %%
#Import dark field data for 60nm NP on Au only following etch
df_meas_3 = data_f_7['OceanOpticsSpectrometer']

# %%
#Put all data into arrays
df_store_3 = []
df_bg_store_3 = []
df_ref_store_3 = []
df_plot_3 = []
wl = df_meas_3[df_meas_3.keys()[i]].attrs['wavelengths']

for i in range(0, len(df_meas_3.values())):
    df_store_3.append(df_meas_3.values()[i].value)
    df_bg_store_3.append(df_meas_3[df_meas_3.keys()[i]].attrs['background'])
    df_ref_store_3.append(df_meas_3[df_meas_3.keys()[i]].attrs['reference'])
    df_plot_3.append((df_store_3[i] - df_bg_store_3[i])/(df_ref_store_3[i] - df_bg_store_3[i]))

# %%
#Caluculate average and standard deviations for this data set
av_df_3 = np.mean(df_plot_3, axis=0)
stdv_df_3 = np.std(df_plot_3, axis=0)
stdv_df_n_3 = stdv_df_3/np.sqrt(len(df_plot_3))
av_df_f_3 = sig.savgol_filter(av_df_3, 23, 4)
stdv_df_n_f_3 = sig.savgol_filter(stdv_df_n_3, 23, 4)

# %%
#Plot the average with corresponding standard deviation for 60nm NP NaCl deposited on TiO2/Au
fig1 = plt.figure(1, [7,7])
ax1 = fig1.add_subplot(111)
ax1.plot(wl, av_df_f_2*100, label = "60nm NPs on Au - avg 150 NPs")
ax1.plot(wl, (av_df_f_2 - stdv_df_n_f_2)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_2 + stdv_df_n_f_2)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_2 - stdv_df_n_f_2)*100,
                (av_df_f_2 + stdv_df_n_f_2)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.plot(wl, av_df_f_3*100, label = "60nm NPs on Au after 15 mins 02 etch - avg 160 NPs")
ax1.plot(wl, (av_df_f_3 - stdv_df_n_f_3)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_3 + stdv_df_n_f_3)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_3 - stdv_df_n_f_3)*100,
                (av_df_f_3 + stdv_df_n_f_3)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.set_xlim(410, 900)
ax1.set_ylim(0, 0.13)
ax1.set_ylabel("Scattering (%)", fontsize = 25)
ax1.set_xlabel("Wavelength (nm)", fontsize = 25)
ax1.tick_params(axis='x', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.legend(fontsize = 12)


#ax2 = ax1.twiny()
e = 1243.125/wl
#ax2.set_xlim(ax2.get_xlim())

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/60nm NP DF before after etch.png', bbox_inches='tight')

# %%
#Import dark field data for 60nm NP on Au following +7nm TiO2
data_f_8 = df.open_file(set_current = False)
fname_8 = data_f_8.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/2019-02-13_post_7nm_TiO2.h5

# %%
#Import dark field data for 60nm NP on Au only following etch
df_meas_4 = data_f_8['OceanOpticsSpectrometer']

# %%
#Put all data into arrays
df_store_4 = []
df_bg_store_4 = []
df_ref_store_4 = []
df_plot_4 = []
wl = df_meas_4[df_meas_4.keys()[0]].attrs['wavelengths']
for i in range(0, len(df_meas_4)):
    df_store_4.append(df_meas_4.values()[i].value)
    df_bg_store_4.append(df_meas_4[df_meas_4.keys()[i]].attrs['background'])
    df_ref_store_4.append(df_meas_4[df_meas_4.keys()[i]].attrs['reference'])
    df_plot_4.append((df_store_4[i] - df_bg_store_4[i])/(df_ref_store_4[i] - df_bg_store_4[i]))
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in divide
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_plot_4[137]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-191-f4770a3e8d71> in <module>()
# ----> 1 df_plot_4[137]
#
# IndexError: list index out of range

# %%
#Caluculate average and standard deviations for this data set
av_df_4 = np.mean(df_plot_4[137:], axis=0)
stdv_df_4 = np.std(df_plot_4[137:], axis=0)
stdv_df_n_4 = stdv_df_4/np.sqrt(len(df_plot_4[137:]))
av_df_f_4 = sig.savgol_filter(av_df_4, 23, 4)
stdv_df_n_f_4 = sig.savgol_filter(stdv_df_n_4, 23, 4)
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\scipy\signal\_savitzky_golay.py:187: RankWarning: Polyfit may be poorly conditioned
#   xx_edge, polyorder)
# C:\Users\alexc\Anaconda2\lib\site-packages\scipy\signal\_savitzky_golay.py:187: RankWarning: Polyfit may be poorly conditioned
#   xx_edge, polyorder)

# %%
#Plot the average with corresponding standard deviation for 60nm NP NaCl deposited on TiO2/Au
fig1 = plt.figure(1, [7,7])
ax1 = fig1.add_subplot(111)
ax1.plot(wl, av_df_f_1*100, label = "60nm NPs on Au - avg 150 NPs")
ax1.plot(wl, (av_df_f_1 - stdv_df_n_f_1)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_1 + stdv_df_n_f_1)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_1 - stdv_df_n_f_1)*100,
                (av_df_f_1 + stdv_df_n_f_1)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.plot(wl, av_df_f_4*100, label = "60nm NPs on Au after 7nm TiO2 - avg 137 NPs")
ax1.plot(wl, (av_df_f_4 - stdv_df_n_f_4)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_4 + stdv_df_n_f_4)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_4 - stdv_df_n_f_4)*100,
                (av_df_f_4 + stdv_df_n_f_4)*100, color = "r", 
                alpha = 0.1, zorder = 3)

ax1.set_xlim(410, 900)
ax1.set_ylim(0, 0.13)
ax1.set_ylabel("Scattering (%)", fontsize = 25)
ax1.set_xlabel("Wavelength (nm)", fontsize = 25)
ax1.tick_params(axis='x', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.legend(fontsize = 12)


#ax2 = ax1.twiny()
e = 1243.125/wl
#ax2.set_xlim(ax2.get_xlim())

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/60nm NP on 3nmTiO2 after 7nm TiO2.png', bbox_inches='tight')

# %%
#Import dark field data for 60nm NP on Au following +7nm TiO2
data_f_9 = df.open_file(set_current = False)
fname_9 = data_f_9.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/O2 etching NPs on Au/2019-02-18_etching_NPs_on_TiO2.h5

# %%
data_f_9.close()

# %%
#Import dark field data for 60nm NP on TiO2 following etch
df_meas_5 = data_f_9['OceanOpticsSpectrometer']

# %%
#Define wl and crop out bad values
wl = df_meas_5[df_meas_5.keys()[i]].attrs['wavelengths']
wl = wl[10:1030]

# %%
df_meas_5[df_meas_5.keys()[0]].attrs['background'][10:1030]
# Out:
# array([ 1632.,  1629.,  1633., ...,  1634.,  1666.,  1635.])

# %%
#Sort data vs timestamp
data_w_ts_5 = []
data_w_ts_raw_5 = []
mi = 10
mx = 1030
for i in range (0, len(df_meas_5.values())):
    back = df_meas_5[df_meas_5.keys()[i]].attrs['background'][mi:mx]
    ref = df_meas_5[df_meas_5.keys()[i]].attrs['reference'][mi:mx]
    raw = df_meas_5.values()[i].value[mi:mx]
    df_NPs = (raw - back)/(ref-back)
    df_NPs_raw = (raw - back)
    current_timestamp =  datetime.datetime.strptime(
                df_meas_5.values()[i].attrs['creation_timestamp'][:19], "%Y-%m-%dT%H:%M:%S")
    s = (current_timestamp-datetime.datetime(1970,1,1)).total_seconds()
    df_w_ts_5 = np.append(df_NPs, s)
    df_w_ts_raw_5 = np.append(df_NPs_raw, s)
    data_w_ts_5.append(df_w_ts_5)
    data_w_ts_raw_5.append(df_w_ts_raw_5)

# %%
data_w_ts_sorted_5 = sorted(data_w_ts_5,key=lambda x: x[-1])
data_sorted_5 = np.array(data_w_ts_sorted_5)[:,:len(data_w_ts_sorted_5[0])-1]

data_w_ts_sorted_raw_5 = sorted(data_w_ts_raw_5,key=lambda x: x[-1])
data_sorted_raw_5 = np.array(data_w_ts_sorted_raw_5)[:,:len(data_w_ts_sorted_raw_5[0])-1]

# %%
data_sorted_5[:, [400:500]]
# Out:
#   File "<ipython-input-74-ca61cdb2a293>", line 1
#     data_sorted_5[:, [400:500]]
#                          ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)
av_df_3nmTiO2 = np.mean(data_sorted_5[0:50], axis=0)
ax.plot(wl,av_df_3nmTiO2)
ax.set_ylim(0,0.002)
ax.set_xlim(390, 800)
# Out:
# (390, 800)

# %%
sm_factor = 1
thresh_guess = 0.5
lw_guess_sm = 40

#Caluculate average and standard deviations for this 60nm AuNPs on 3nm TiO2
av_df_3nmTiO2 = np.mean(data_sorted_5[0:50], axis=0)
stdv_df_3nmTiO2 = np.std(data_sorted_5[0:50], axis=0)
stdv_df_3nmTiO2 = stdv_df_3nmTiO2/np.sqrt(len(data_sorted_5[0:50]))
av_df_f_3nmTiO2 = sig.savgol_filter(av_df_3nmTiO2, 23, sm_factor)
stdv_df_f_3nmTiO2 = sig.savgol_filter(stdv_df_3nmTiO2, 23, sm_factor)

pk_ind_f_3nmTiO2 = peakutils.indexes(av_df_f_3nmTiO2,thres = thresh_guess, min_dist = lw_guess_sm*2)
pk_wls_f_3nmTiO2 = wl[pk_ind_f_3nmTiO2]
pk_ins_f_3nmTiO2 = av_df_f_3nmTiO2[pk_ind_f_3nmTiO2]  

#Caluculate average and standard deviations for 60nm AuNPs on 3nm TiO2 after etch for 10mins
av_df_3nmTiO2_PE = np.mean(data_sorted_5[51:135], axis=0)
stdv_df_3nmTiO2_PE = np.std(data_sorted_5[51:135], axis=0)
stdv_df_3nmTiO2_PE = stdv_df_3nmTiO2_PE/np.sqrt(len(data_sorted_5[51:135]))
av_df_f_3nmTiO2_PE = sig.savgol_filter(av_df_3nmTiO2_PE, 23, sm_factor)
stdv_df_f_3nmTiO2_PE = sig.savgol_filter(stdv_df_3nmTiO2_PE, 23, sm_factor)

pk_ind_f_3nmTiO2_PE = peakutils.indexes(av_df_f_3nmTiO2_PE,thres = thresh_guess, min_dist = lw_guess_sm*2)
pk_wls_f_3nmTiO2_PE = wl[pk_ind_f_3nmTiO2_PE]
pk_ins_f_3nmTiO2_PE = av_df_f_3nmTiO2_PE[pk_ind_f_3nmTiO2_PE] 

#Caluculate average and standard deviations for 60nm AuNPs on 3nm TiO2 after etch for 10mins
av_df_3nmTiO2_PE_2 = np.mean(data_sorted_5[136:], axis=0)
stdv_df_3nmTiO2_PE_2 = np.std(data_sorted_5[136:], axis=0)
stdv_df_3nmTiO2_PE_2 = stdv_df_3nmTiO2_PE_2/np.sqrt(len(data_sorted_5[136:]))
av_df_f_3nmTiO2_PE_2 = sig.savgol_filter(av_df_3nmTiO2_PE_2, 23, sm_factor)
stdv_df_f_3nmTiO2_PE_2 = sig.savgol_filter(stdv_df_3nmTiO2_PE_2, 23, sm_factor)

pk_ind_f_3nmTiO2_PE_2 = peakutils.indexes(av_df_f_3nmTiO2_PE_2,thres = thresh_guess, min_dist = lw_guess_sm*2)
pk_wls_f_3nmTiO2_PE_2 = wl[pk_ind_f_3nmTiO2_PE_2]
pk_ins_f_3nmTiO2_PE_2 = av_df_f_3nmTiO2_PE_2[pk_ind_f_3nmTiO2_PE_2]

# %%
peakutils.indexes(av_df_f_3nmTiO2,thres = thresh_guess, min_dist = lw_guess_sm*2)
# Out:
# array([184, 332, 425, 512, 601, 684, 815, 917, 999])

# %%
plt.plot(pk_wls_f, pk_ins_f)

# %%
#Plot the average with corresponding standard deviation for 60nm NP NaCl deposited on TiO2/Au
fig1 = plt.figure(1, [7,7])
ax1 = fig1.add_subplot(111)
ax1.plot(wl, av_df_f_3nmTiO2*100, label = "60nm NPs on 3nm TiO2 - avg 51 NPs")
ax1.plot(wl, (av_df_f_3nmTiO2 - stdv_df_f_3nmTiO2)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_3nmTiO2 + stdv_df_f_3nmTiO2)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_3nmTiO2 - stdv_df_f_3nmTiO2)*100,
                (av_df_f_3nmTiO2 + stdv_df_f_3nmTiO2)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.scatter(pk_wls_f_3nmTiO2, pk_ins_f_3nmTiO2*100)
for i, txt in enumerate(np.round(pk_wls_f_3nmTiO2)):
    ax1.annotate(txt, (pk_wls_f_3nmTiO2[i], pk_ins_f_3nmTiO2[i]*100))

ax1.plot(wl, av_df_f_3nmTiO2_PE*100, label = "60nm NPs on 3nm TiO2 after 10min O2 etch - avg 91 NPs")
ax1.plot(wl, (av_df_f_3nmTiO2_PE - stdv_df_f_3nmTiO2_PE)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_3nmTiO2_PE + stdv_df_f_3nmTiO2_PE)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_3nmTiO2_PE - stdv_df_f_3nmTiO2_PE)*100,
                (av_df_f_3nmTiO2_PE + stdv_df_f_3nmTiO2_PE)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.scatter(pk_wls_f_3nmTiO2_PE, pk_ins_f_3nmTiO2_PE*100)
for i, txt in enumerate(np.round(pk_wls_f_3nmTiO2_PE)):
    ax1.annotate(txt, (pk_wls_f_3nmTiO2_PE[i], pk_ins_f_3nmTiO2_PE[i]*100))

ax1.plot(wl, av_df_f_3nmTiO2_PE_2*100, label = "60nm NPs on 3nm TiO2 after 20nm O2 etch - avg 85 NPs")
ax1.plot(wl, (av_df_f_3nmTiO2_PE_2 - stdv_df_f_3nmTiO2_PE_2)*100, alpha = 0.5, color = "r", linestyle = "--")
ax1.plot(wl, (av_df_f_3nmTiO2_PE_2 + stdv_df_f_3nmTiO2_PE_2)*100, alpha = 0.5, color = "r",  linestyle = "--")
ax1.fill_between(wl, (av_df_f_3nmTiO2_PE_2 - stdv_df_f_3nmTiO2_PE_2)*100,
                (av_df_f_3nmTiO2_PE_2 + stdv_df_f_3nmTiO2_PE_2)*100, color = "r", 
                alpha = 0.1, zorder = 3)
ax1.scatter(pk_wls_f_3nmTiO2_PE_2, pk_ins_f_3nmTiO2_PE_2*100)
for i, txt in enumerate(np.round(pk_wls_f_3nmTiO2_PE_2)):
    ax1.annotate(txt, (pk_wls_f_3nmTiO2_PE_2[i], pk_ins_f_3nmTiO2_PE_2[i]*100))

ax1.set_xlim(410, 810)
ax1.set_ylim(0, 0.13)
ax1.set_ylabel("Scattering (%)", fontsize = 25)
ax1.set_xlabel("Wavelength (nm)", fontsize = 25)
ax1.tick_params(axis='x', labelsize=15)
ax1.tick_params(axis='y', labelsize=15)
ax1.legend(fontsize = 12)


#ax2 = ax1.twiny()
e = 1243.125/wl
#ax2.set_xlim(ax2.get_xlim())

fig1.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/NPoM TiO2 Solar Cell/60nm NP on 3nmTiO2 after O2 etch.png', bbox_inches='tight')

#Take d_gap = 3.1 and n_gap = 2.2 to give a coupled mode position of 677nm. 
#Increase gap size at this refractive index to give a minimum thickness of 0.5-0.6nm for citrate assuming it has n = 2.2
