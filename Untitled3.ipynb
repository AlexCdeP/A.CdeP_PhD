# %%
#Code for raman

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
# %matplotlib inline
import nplab.datafile as df
import scipy.signal as sig
from scipy import stats
import scipy.constants as const
import peakutils
import numpy as np
import datetime
from peakutils.plot import plot as pplot
from parula import cm_data
from matplotlib.colors import LinearSegmentedColormap 
from matplotlib.collections import LineCollection
import os
import Alexsdatafuncs
import matplotlib.cm as cm
import time
import scipy.integrate as integrate
import scipy.special as special

# %%
parula_map = LinearSegmentedColormap.from_list('parula', cm_data)
copper_map = LinearSegmentedColormap.from_list('copper', cm_data)
colours_1 = cm.viridis(np.linspace(0,1,500))
colours_2 = cm.hot(np.linspace(0,1,500))
Alex_data = Alexsdatafuncs.data_manipulators()
Alex_plot = Alexsdatafuncs.plotting_funcs()

# %%
data_f = df.open_file(set_current = False)
fname = data_f.filename
# Out:
# C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Boron Nitride spacer/Trilayer hBN/20190410_Alex_CdeP/2019-04-10.h5

# %%
data_f.show_gui()
# Out:
# Running GUI, this will block the command line until the window is closed.

# %%
p23_DF = data_f["05-11-18_tri2/DF_P23_after_0"]
p23_DF_aft = data_f["05-11-18_tri2/DF_P23_after2_0"]
bg = p23_DF.attrs["background"]
ref = p23_DF.attrs["reference"]
wl_DF = p23_DF.attrs["wavelengths"]
p23_DF = (p23_DF -  bg)/(ref - bg)
p23_DF_aft= (p23_DF_aft -  bg)/(ref - bg)
# Out:
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in divide
#
# C:\Users\alexc\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in divide
#   import sys

# %%
p23_Ram = data_f["05-11-18_tri2/P23 1mW_0"]

# %%
fig = plt.figure(1, figsize = (7,2))
ax = fig.add_subplot(111)
ax.plot(wl_DF, p23_DF*100)
ax.set_xlim(min(p23_Ram.attrs["wavelengths"]), max(p23_Ram.attrs["wavelengths"]))
ax.set_ylim(0,  0.015*100)
ax.set_ylabel("Scattering (%)")
ax.set_xlabel("Wavelength (nm)")
fig.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Boron Nitride spacer/Trilayer hBN/20190410_Alex_CdeP/hBNDFP23_bef.png', bbox_inches='tight')

# %%
fig = plt.figure(1, figsize = (7,2))
ax = fig.add_subplot(111)
ax.plot(wl_DF, p23_DF_aft*100)
ax.set_xlim(min(p23_Ram.attrs["wavelengths"]), max(p23_Ram.attrs["wavelengths"]))
ax.set_ylim(0,  0.015*100)
ax.set_ylabel("Scattering (%)")

fig.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Boron Nitride spacer/Trilayer hBN/20190410_Alex_CdeP/hBNDFP23_aft.png', bbox_inches='tight')

# %%
fig = plt.figure(1, figsize = (7,7))
ax = fig.add_subplot(111)
time = np.linspace(0, 120, 40)
print len(time), len(p23_Ram)
ax.imshow(p23_Ram, extent=[min(p23_Ram.attrs["wavelengths"]), max(p23_Ram.attrs["wavelengths"]),
                    0, 120], aspect = 'auto', 
                            cmap = cm.inferno)
ax.set_xlabel('Wavelengths (nm)')
ax.set_ylabel('Time (s)')
#ax.plot(p23_DF_aft.attrs["wavelengths"], p23_DF_aft)
#ax.set_xlim(400, 950)

fig.savefig('C:/Users/alexc/OneDrive - University Of Cambridge/Documents/PhD Project/Projects/Boron Nitride spacer/Trilayer hBN/20190410_Alex_CdeP/hBNRamanP23.png', bbox_inches='tight')
# Out:
# 40 40
